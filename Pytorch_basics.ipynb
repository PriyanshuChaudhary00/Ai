# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyanshuChaudhary00/Ai/blob/main/Pytorch_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# Auto grad

# %%
x = torch.tensor(3.0 , requires_grad=True)
y = x**2
print(x , y)
# Out:
# tensor(3., requires_grad=True) tensor(9., grad_fn=<PowBackward0>)

# %%
z = y**3 + 10

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(1458.)

# %% [markdown]
# Training Pipeline
